# %% [markdown]
# # IO analysis
#
# * https://rdrr.io/cran/ioanalysis/
# * https://www.cso.ie/en/statistics/nationalaccounts/supplyandusetablesforireland/
# * https://www.wider.unu.edu/database/2013-social-accounting-matrix-zimbabwe
# * http://www.real.illinois.edu/pyio/
# * https://cran.r-project.org/web/packages/ioanalysis/ioanalysis.pdf

# %%
import pandas as pd

# %%
t = pd.read_excel('P-SAUCUP2016TBL01.xlsx', header=4,index_col=1)

# %%
t=t.iloc[1:,1:]

# %%
cols=t.columns
n=cols[0]

# %%
print(t.sum())
# Out:
# Agriculture, forestry and fishing                              1.709450e+04
# Mining, quarrying and extraction                               2.691184e+03
# Manufacture of food products                                   4.535295e+04
# Manufacture of beverages and tobacco products                  5.421200e+03
# Manufacture of textiles                                        5.060820e+02
#                                                                    ...
# Private households with employed persons                       1.189676e+02
# Total domestic                                                 1.081357e+06
# Imports c.i.f. (cost, insurance & freight inclusive)           8.525191e+05
# Taxes on products                                              4.214260e+04
# Total supply at purchasers' prices (= total use in Table 2)    2.534967e+06
# Length: 62, dtype: float64

# %%
x=pd.read_csv('WP2018-139-Data-for-a-2013-Zimbabwe-SAM.csv')

# %%
x
# Out:
#     Unnamed: 0    alagr    asagr  afore  afish  amcoa  amnfm  amoth  afood  \
# 0        alagr     -        -      -      -      -      -      -      -
# 1        asagr     -        -      -      -      -      -      -      -
# 2        afore     -        -      -      -      -      -      -      -
# 3        afish     -        -      -      -      -      -      -      -
# 4        amcoa     -        -      -      -      -      -      -      -
# ..         ...      ...      ...    ...    ...    ...    ...    ...    ...
# 96        dtax     -        -      -      -      -      -      -      -
# 97         s-i     -        -      -      -      -      -      -      -
# 98        dstk     -        -      -      -      -      -      -      -
# 99         row     -        -      -      -      -      -      -      -
# 100      total   1,365    1,047    141      1    657    947     93    915
#
#      atobm  ...   atax     stax   mtax     dtax      s-i   dstk      row  \
# ...
